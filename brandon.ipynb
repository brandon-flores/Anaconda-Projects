# %%
import skimage

# %%
import scipy.misc

# %%
import matplotlib.pyplot as plt
smile = scipy.misc.imread('smile.jpg')
plt.imshow(smile)
plt.show()

# %%
smile.shape
# Out:
# (478L, 628L, 3L)

# %%
from skimage import color
from skimage import io

greysmile = color.rgb2gray(smile)
greysmile.shape
# Out:
# (478L, 628L)

# %%
plt.subplot(121)
plt.imshow(edges, cmap=plt.cm.gray)
plt.subplot(122)
plt.imshow(corners, cmap=plt.cm.gray)
plt.show(
# Out:
#   File "<ipython-input-9-583d16e1bd91>", line 5
#     plt.show(
#              ^
# SyntaxError: invalid syntax

# %%
plt.subplot(121)
plt.imshow(edges, cmap=plt.cm.gray)
plt.subplot(122)
plt.imshow(corners, cmap=plt.cm.gray)
plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-10-f402ddab888a> in <module>()
#       1 plt.subplot(121)
# ----> 2 plt.imshow(edges, cmap=plt.cm.gray)
#       3 plt.subplot(122)
#       4 plt.imshow(corners, cmap=plt.cm.gray)
#       5 plt.show()
#
# NameError: name 'edges' is not defined

# %%
from skimage import feature
edges=feature.canny(greysmile)
corners=feature.corner_harris(greysmile)

# %%
plt.imshow(edges, cmap=plt.cm.gray)
plt.subplot(122)
plt.imshow(corners, cmap=plt.cm.gray)
plt.show()

# %%
plt.subplot(121)
plt.imshow(edges, cmap=plt.cm.gray)
plt.subplot(122)
plt.imshow(corners, cmap=plt.cm.gray)
plt.show()
